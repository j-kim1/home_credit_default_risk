# %%
import pandas as pd

# %%
d1 = {'customer_id':[1,2,3,4,5,6],
      'product':['Oven', 'Oven', 'Oven', 'Television', 'Television', 'Television']}
df1 = pd.DataFrame(d1)

d2 = {'customer_id':[2,4,6,8],
      'state':['California', 'California', 'Texas', 'Hell']}
df2= pd.DataFrame(d2)

# %%
df1
# Out:
#    customer_id     product
# 0            1        Oven
# 1            2        Oven
# 2            3        Oven
# 3            4  Television
# 4            5  Television
# 5            6  Television

# %%
df2
# Out:
#    customer_id       state
# 0            2  California
# 1            4  California
# 2            6       Texas
# 3            8        Hell

# %% [markdown]
# ### Inner Join

# %%
inner_join_result = pd.merge(df1, df2, on='customer_id', how='inner')
inner_join_result
# Out:
#    customer_id     product       state
# 0            2        Oven  California
# 1            4  Television  California
# 2            6  Television       Texas

# %%
inner_join_result = df1.merge(df2, on = 'customer_id', how='inner')
inner_join_result
# Out:
#    customer_id     product       state
# 0            2        Oven  California
# 1            4  Television  California
# 2            6  Television       Texas

# %% [markdown]
# ### Left Outer Join

# %%
left_outer_join_result = pd.merge(df1, df2, on='customer_id', how='left')
left_outer_join_result
# Out:
#    customer_id     product       state
# 0            1        Oven         NaN
# 1            2        Oven  California
# 2            3        Oven         NaN
# 3            4  Television  California
# 4            5  Television         NaN
# 5            6  Television       Texas

# %%
df1.merge(df2, on='customer_id', how='left')
# Out:
#    customer_id     product       state
# 0            1        Oven         NaN
# 1            2        Oven  California
# 2            3        Oven         NaN
# 3            4  Television  California
# 4            5  Television         NaN
# 5            6  Television       Texas

# %% [markdown]
# ### Right Outer Join

# %%
right_outer_join_result = pd.merge(df1, df2, on='customer_id', how='right')
right_outer_join_result
# Out:
#    customer_id     product       state
# 0            2        Oven  California
# 1            4  Television  California
# 2            6  Television       Texas
# 3            8         NaN        Hell

# %%
df1.merge(df2, on='customer_id', how='right')
# Out:
#    customer_id     product       state
# 0            2        Oven  California
# 1            4  Television  California
# 2            6  Television       Texas
# 3            8         NaN        Hell

# %%
df2.merge(df1, on='customer_id', how='left')
# Out:
#    customer_id       state     product
# 0            2  California        Oven
# 1            4  California  Television
# 2            6       Texas  Television
# 3            8        Hell         NaN

# %% [markdown]
# ### Full outer join

# %%
full_outer_join_result = pd.merge(df1, df2, on='customer_id', how='outer')
full_outer_join_result
# Out:
#    customer_id     product       state
# 0            1        Oven         NaN
# 1            2        Oven  California
# 2            3        Oven         NaN
# 3            4  Television  California
# 4            5  Television         NaN
# 5            6  Television       Texas
# 6            8         NaN        Hell

# %%
df1.merge(df2, on='customer_id', how='outer')
# Out:
#    customer_id     product       state
# 0            1        Oven         NaN
# 1            2        Oven  California
# 2            3        Oven         NaN
# 3            4  Television  California
# 4            5  Television         NaN
# 5            6  Television       Texas
# 6            8         NaN        Hell

# %%
df2.merge(df1, on='customer_id', how='outer')
# Out:
#    customer_id       state     product
# 0            2  California        Oven
# 1            4  California  Television
# 2            6       Texas  Television
# 3            8        Hell         NaN
# 4            1         NaN        Oven
# 5            3         NaN        Oven
# 6            5         NaN  Television

# %% [markdown]
# ### Groupby

# %%
import pandas as pd
cust_dict = {
    'customer_name':['Alice', 'Tom', 'James', 'Yerin', 'Min', 'Katherine', 'John', 'Park', 'Maria', 'Derik', 'Jin'],
    'cust_country':['US', 'GB', 'US', 'KOR', 'KOR', 'GB', 'US', 'KOR', 'US', 'GB', 'KOR'],
    'gender':['F', 'M', 'M', 'F', 'M', 'F', 'M', 'M', 'F', 'M', 'F'],
    'grade':[3, 1, 2, 5, 4, 3, 5, 7, 2, 4, 5],
    'age':[25, 34, 26, 33, 67, 29, 54, 21, 77, 29, 16]
}
customer = pd.DataFrame(cust_dict)

customer.head(11)
# Out:
#    customer_name cust_country gender  grade  age
# 0          Alice           US      F      3   25
# 1            Tom           GB      M      1   34
# 2          James           US      M      2   26
# 3          Yerin          KOR      F      5   33
# 4            Min          KOR      M      4   67
# 5      Katherine           GB      F      3   29
# 6           John           US      M      5   54
# 7           Park          KOR      M      7   21
# 8          Maria           US      F      2   77
# 9          Derik           GB      M      4   29
# 10           Jin          KOR      F      5   16

# %% [markdown]
# #### SQL Group by
# SELECT cust_country, sum(grade) sum_grade, max(grade) max_grade, avg(age) avg_age, max(age) max_age FROM customer group by cust_country

# %% [markdown]
# #### Pandas Groupby

# %% [markdown]
# * DataFrameGroupby generation using Groupby key column

# %%
cust_group = customer.groupby('cust_country')
type(cust_group)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
cust_group.head()
# Out:
#    customer_name cust_country gender  grade  age
# 0          Alice           US      F      3   25
# 1            Tom           GB      M      1   34
# 2          James           US      M      2   26
# 3          Yerin          KOR      F      5   33
# 4            Min          KOR      M      4   67
# 5      Katherine           GB      F      3   29
# 6           John           US      M      5   54
# 7           Park          KOR      M      7   21
# 8          Maria           US      F      2   77
# 9          Derik           GB      M      4   29
# 10           Jin          KOR      F      5   16

# %% [markdown]
# * Aggregation column - Call API for each column

# %%
cust_agg = pd.DataFrame()
cust_agg
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
cust_agg = pd.DataFrame()
cust_agg['sum_grade'] = cust_group['grade'].sum()
cust_agg['max_grade'] = cust_group['grade'].max()
cust_agg.head()
# Out:
#               sum_grade  max_grade
# cust_country
# GB                    8          4
# KOR                  21          7
# US                   12          5

# %%
cust_agg['avg_age'] = cust_group['age'].mean()
cust_agg['max_age'] = cust_group['age'].max()
cust_agg.head()
# Out:
#               sum_grade  max_grade    avg_age  max_age
# cust_country
# GB                    8          4  30.666667       34
# KOR                  21          7  34.250000       67
# US                   12          5  45.500000       77

# %%
# Groupby key column -> Index of result dataframe
print(cust_agg.index.name)
cust_agg = cust_agg.reset_index()
cust_agg.head()
# Out:
# cust_country
#   cust_country  sum_grade  max_grade    avg_age  max_age
# 0           GB          8          4  30.666667       34
# 1          KOR         21          7  34.250000       67
# 2           US         12          5  45.500000       77

# %% [markdown]
# #### application of agg()

# %%
cust_agg1 = cust_group['grade'].agg(['sum', 'max'])
cust_agg2 = cust_group['age'].agg(['mean', 'max'])
print(cust_agg1.head())
print(cust_agg2.head())
# Out:
#               sum  max
# cust_country
# GB              8    4
# KOR            21    7
# US             12    5
#                    mean  max
# cust_country
# GB            30.666667   34
# KOR           34.250000   67
# US            45.500000   77

# %%
cust_agg = cust_agg1.merge(cust_agg2, on='cust_country', how='left')
cust_agg.head()
# Out:
#               sum  max_x       mean  max_y
# cust_country
# GB              8      4  30.666667     34
# KOR            21      7  34.250000     67
# US             12      5  45.500000     77

# %%
# column name setting 
cust_agg = pd.DataFrame()
cust_agg[['sum_grade', 'max_grade']] = cust_group['grade'].agg(['sum', 'max'])
cust_agg[['avg_age', 'max_age']] = cust_group['age'].agg(['mean', 'max'])
cust_agg.head()
# Out:
#               sum_grade  max_grade    avg_age  max_age
# cust_country
# GB                    8          4  30.666667       34
# KOR                  21          7  34.250000       67
# US                   12          5  45.500000       77

# %% [markdown]
# #### agg() with dictionary composed of aggregation column and function list

# %%
agg_dict={'grade':['sum','max'],
          'age':['mean', 'max']}
cust_agg = cust_group.agg(agg_dict)
cust_agg.head()
# Out:
#              grade            age
#                sum max       mean max
# cust_country
# GB               8   4  30.666667  34
# KOR             21   7  34.250000  67
# US              12   5  45.500000  77

# %%
print(cust_agg.columns)
# Out:
# MultiIndex([('grade',  'sum'),
#             ('grade',  'max'),
#             (  'age', 'mean'),
#             (  'age',  'max')],
#            )

# %%
['_'.join(column) for column in cust_agg.columns]
# Out:
# ['grade_sum', 'grade_max', 'age_mean', 'age_max']

# %%
#### change column name of groupby results
cust_agg.columns = ['_'.join(column) for column in cust_agg.columns]
cust_agg.head()
# Out:
#               grade_sum  grade_max   age_mean  age_max
# cust_country
# GB                    8          4  30.666667       34
# KOR                  21          7  34.250000       67
# US                   12          5  45.500000       77

# %% [markdown]
# ### Pandas Group by Case When

# %% [markdown]
# #### SQL
# SELECT cust_country, sum(grade) total_sum,
# Sum(case when gender=='M' then grade end) male_sum,
# Sum(case when gender=='F' then grade end) female_sum FROM customer GROUP BY cust_country

# %%
customer
# Out:
#    customer_name cust_country gender  grade  age
# 0          Alice           US      F      3   25
# 1            Tom           GB      M      1   34
# 2          James           US      M      2   26
# 3          Yerin          KOR      F      5   33
# 4            Min          KOR      M      4   67
# 5      Katherine           GB      F      3   29
# 6           John           US      M      5   54
# 7           Park          KOR      M      7   21
# 8          Maria           US      F      2   77
# 9          Derik           GB      M      4   29
# 10           Jin          KOR      F      5   16

# %% [markdown]
# #### filtering with case when condition, and make dataframe separately

# %%
cond_male = customer['gender']=='M'
cond_female = customer['gender']=='F'
cust_male = customer[cond_male]
cust_female = customer[cond_female]

# %%
cust_female
# Out:
#    customer_name cust_country gender  grade  age
# 0          Alice           US      F      3   25
# 3          Yerin          KOR      F      5   33
# 5      Katherine           GB      F      3   29
# 8          Maria           US      F      2   77
# 10           Jin          KOR      F      5   16

# %% [markdown]
# #### Apply Groupby to original df

# %%
cust_agg = customer.groupby('cust_country')['grade'].sum()
cust_agg = cust_agg.reset_index()
cust_agg.head()
# Out:
#   cust_country  grade
# 0           GB      8
# 1          KOR     21
# 2           US     12

# %% [markdown]
# #### Apply Groupby to filtered df

# %%
cust_male_agg = cust_male.groupby('cust_country')['grade'].sum()
cust_female_agg = cust_female.groupby('cust_country')['grade'].sum()
cust_male_agg = cust_male_agg.reset_index()
cust_female_agg = cust_female_agg.reset_index()

# %%
cust_male_agg
# Out:
#   cust_country  grade
# 0           GB      5
# 1          KOR     11
# 2           US      7

# %% [markdown]
# #### Merge data set

# %%
cust_agg = cust_agg.merge(cust_male_agg, on = 'cust_country', how = 'left')
cust_agg = cust_agg.merge(cust_female_agg, on = 'cust_country', how = 'left')
cust_agg.head()
# Out:
#   cust_country  grade_x  grade_y  grade
# 0           GB        8        5      3
# 1          KOR       21       11     10
# 2           US       12        7      5

# %%
cust_agg.columns = ['cust_country', 'sum_grade', 'sum_male_grade', 'sum_female_grade']
cust_agg
# Out:
#   cust_country  sum_grade  sum_male_grade  sum_female_grade
# 0           GB          8               5                 3
# 1          KOR         21              11                10
# 2           US         12               7                 5
